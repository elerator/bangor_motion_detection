# %%
import os #Walk files
import re #REGEX
import numpy as np
import cv2 #Farneback
import matplotlib.pyplot as plt 
import pickle #Dump to files

class ma(object):
    @staticmethod
    def saveMovieMotionHistograms(directory):
        """ Computes the weighted histograms of motion directions between frames 
            for each .mov video in a filetree, saves maps representing one video to files          
            Args: 
                dirctory: Uppermost directory containing subfolders with at least one .mov file
        """
        # traverse directory tree process motion and save result if a .mov file is found
        for root, dirs, files in os.walk(directory):
            for file in files:
                #root+file represents whole path. If it ends with .mov...
                if(re.match(".*\\.mov", root+file)):
                    filepath = root+"\\"+file
                    print('Processing: ' + filepath)
                    mapOfCurrentVideo = ma.processMotionInClip(cv2.VideoCapture(filepath))
                    #Create 
                    #os.makedirs(os.path.dirname(writeFilepath), exist_ok=True)
                    with open(root +"\\"+file + ".motHistMap", 'wb') as handle:
                        pickle.dump(mapOfCurrentVideo, handle, protocol=pickle.HIGHEST_PROTOCOL)
    

    
    @staticmethod
    def loadMotionHistogramsToHeightMaps(directory):
        """ Loads the previosly saved weighted histograms of motion directions between frames 
            for each .mov video from any nested folder structure        
            Args: 
                directory: Uppermost directory containing subfolders with at least one .mov file
            Returns: Nested dictionary (map) where the uppermost layer represents the foldernames containing
                the videos i.e. stimulus categories. The latter are the keys on the next level. The corresponding
                values are the dictionaries mapping framenumbers to weighted motion histograms
        """
        motionHistMaps = {}
        fileIdentifierToData = {}
        
        for root, dirs, files in os.walk(directory):
            fileIdentifierToData = {}
            foldername = root.split("\\")[-1] #isolate last part of path
            for file in files:
                if(re.match(".*\\.motHistMap", root+file)):
                    filepath = root+"\\"+file
                    fileIdentifier = file.split(".")[0] #isolate filename-part before .
                    #print('Folder: ' + foldername )
                    #print('Fileidentifier: ' + fileIdentifier)

                    with open(filepath, 'rb') as handle:
                        heightMap = ma.heightMapOfVideosMotionHistograms(pickle.load(handle))
                        #print(type(heightMap[0][0]))
                    fileIdentifierToData[fileIdentifier] = heightMap
                    #Apperently this notation doesn't work in a loop:
                    #motionHistMaps[foldername] = {fileIdentifier:heightMap}
                    
                    motionHistMaps[foldername] = fileIdentifierToData
        return motionHistMaps         
        
        """     ##This is how one would save the files to a one level nested dict where numbers from 0 represent files/folders   
        motionHistMaps = {}
        nothingInThere = True # we assume there is no .motHistMap in there
        currentFolder = 0
        
        for root, dirs, files in os.walk(directory):
            currentFile = 0

            for file in files:
                if(re.match(".*\\.motHistMap", root+file)):
                    nothingInThere = False
                    filepath = root+"\\"+file
                    print('Loading: ' + filepath)

                    with open(filepath, 'rb') as handle:
                        motionHistMaps[currentFolder] = {currentFile:pickle.load(handle) }
                    currentFile += 1
            if not nothingInThere:
                currentFolder +=1 # Now there are no more files in current root -> New root
                nothingInThere = True # we assume there is no .mov in there
        return motionHistMaps         
        """                   
                    
    
    @staticmethod
    def plotHistogram360(values, title):
        """ Plots histogram with 36 bins to the jupyter notebook
            Args:
                values: 1D array containing 36 values
                title: Title of the histogram
        """
        bins = (np.arange(36)*10)-170 #start at -170. Go up in steps of 10 to 180
        values = np.abs(values)#Discard minus
        y_pos = np.arange(len(values)) -17
        plt.bar(y_pos, values)
        plt.xticks([-18,-9, 0, 9, 18],['-180°',"-90°","0°","90°", "180°"])
        plt.ylabel('Amount of motion')
        plt.title(title)
        plt.show()
        
    @staticmethod
    def plotHeightMap(heightMap):
        from pylab import pcolor, show, yticks, xticks, colorbar
        pcolor(heightMap, cmap = 'plasma')
        yticks([0,8,17,26,35],[-180,-90,0,90,180,-90,0,90,180])
        colorbar()
        show()
        
    @staticmethod
    def weightedHistogram(pvrs, flow):
        """ Computes a histogram of the motion directions detected by farneback algorithm,
            weights each bin by the strength of motion in the respective direction
        
            Args:
                pvrs: any frame of the video or any other 2d numpy array with the same size
                flow: the return of the Farneback algorithm
            Returns:
                A weighted histogram of motion directions between two frames
        """
        bins = (np.arange(36)*10)-170 #start at -170. Go up in steps of 10 to 180

        
        (dispStrength, dispDir) = ma.computeFrameMeasures(pvrs,flow)
        weightedHist, bin_edges = np.histogram(dispDir.flatten(), weights = dispStrength.flatten(), bins = bins)
        return weightedHist
    
    @staticmethod
    def computeFrameMeasures(pvrs, flow):
        """    Compute the displacement strength (length of displacement vector) and direction 
            Args:
                pvrs: any frame of the video or any other 2d numpy array with the same size
                flow: the return of the Farneback algorithm
            Returns:
                dispStrength: A 2D array representing the strength of the displacement for each 
                pixel detected between two frames

                dispDir: A 2D array representing the direction of the displacement
        """
        dispStrength = np.empty(np.shape(pvrs))
        dispDir = np.empty(np.shape(pvrs))
        dispStrength.fill(-np.finfo('d').max)#Assign - Infinity
        dispDir.fill(-np.finfo('d').max)#Assign - Infinity
        for y in range(0, np.shape(flow)[0]): # For each pixel
            for x in range(0, np.shape(flow)[1]):
                dispStrength[y][x] = np.linalg.norm(flow[y][x]) #equivalent to sqrt(a^2+b^2)
                dispDir[y][x] = np.degrees(np.arctan2(flow[y][x][0],flow[y][x][1])) #returns direction of vector
        return(dispStrength, dispDir)
    
    @staticmethod
    def heightMapOfVideosMotionHistograms(myMap):
        """Computes a height-map represenatation of the weighted motion direction histograms for
            a single video clip
            Args:
                myMap: A map containg pairs of frame number to weighted motion direction histograms
                        for all frames of a video
            Returns:
                arrayHeightMap: 2D array representing one height map per column
        """
        arrayHeightMap = []
        for dir in range(0, len(myMap[0])):#loop through directions (will be Y)
            motionAcrossVideos = []
            for frame in range(0, len(myMap)): #loop through frames (will be X)
                motionAcrossVideos.append(myMap[frame][dir])
            arrayHeightMap.append(np.array(motionAcrossVideos))
        return arrayHeightMap
    
    @staticmethod
    def processMotionInClip(cap):
        """Loops through all frames of a movie clip and computes a weighted histogram
            of motion directions for each pair of subsequent frames
            Args:
                cap: Capture of movie file as returned by cv.VideoCapture("C:/1.mov")
            Returns: Map of integer frame-IDs to weighted histograms of motion directions
        """

        ret, frame1 = cap.read()
        prvs = cv2.cvtColor(frame1, cv2.COLOR_BGR2GRAY)

        frameHistMap = {}

        currentFrame = 0
        while (True): #Continue looping until break
            ret, frame2 = cap.read()
            #if currentFrame == 20: #DEBUGGING
            #    break

            if ret == False: #There is no frame anymore
                print("Reached end of video")
                break
            else:
                print("Loading frame")

                next = cv2.cvtColor(frame2, cv2.COLOR_BGR2GRAY)
                flow = cv2.calcOpticalFlowFarneback(prvs, next, None, 0.5, 3, 15, 2, 5, 1.2, 0)
                frameHistMap[currentFrame] = ma.weightedHistogram(prvs, flow)
                prvs = next
                currentFrame += 1
        return frameHistMap
    
    @staticmethod
    def averageAmountOfMotionToCSV(heightMaps):
        outputFile = "Category;Stimulus;Average amount of motion\n"
        for category, v in heightMaps.items():
            if isinstance(v, dict):
                for stimulus, heightMap in v.items():
                    outputFile = outputFile + category + ";" + stimulus + ";" + str(np.mean(heightMap)) + "\n"
            else:
                  raise ValueError('Toplevel dictionary should only contain dictionaries')
        with open("AverageMotion.csv", "w") as text_file:
            print(outputFile, file=text_file)

# %% [markdown]
# This is the motion analysis utility class (ma) that aims at processing motion within and across video stimuli.
# Author: Michael Gerstenberger 2017

# %% [markdown]
# Testing the computation and strorage of Motion Histograms (Will take up to several hours depending on the machine in use and the number of videos to be processed)

# %%
#Commented out for security reasons (Takes 3 hours)
#ma.saveMovieMotionHistograms('C:\\Users\\Eler\\Documents\\Python Scripts\\Motion Analysis')

# %% [markdown]
# Loading the precomputed maps again

# %%
heightMaps = ma.loadMotionHistogramsToHeightMaps('C:\\Users\\Eler\\Documents\\Python Scripts\\Motion Analysis')

# %% [markdown]
# Test of iterating through the 2 level nested dictionary containing the motion histogram height maps.
# Test of displaying the motion histogram height maps.

# %%
for category, v in heightMaps.items():
    if isinstance(v, dict):
        for stimulus, heightMap in v.items():
            print("- Category    : " + str(category))
            print("--- Stimulus  : " + str(stimulus))
            #Commented out for time reasons
            #ma.plotHeightMap(heightMap)
            print("Average amount of motion" +
                  " (No. of pixels moving * strength of displacement): " + str(np.mean(heightMap)))
            print("\n\n----------------------------------------------------------")
    else:
      raise ValueError('Toplevel dictionary should only contain dictionaries')
# Out:
# - Category    : 05_Sol1_Cel
# --- Stimulus  : Sol_Cel7_P1_FL
# Average amount of motion (No. of pixels moving * strength of displacement): 863.788618318
#
#
# ----------------------------------------------------------
# - Category    : 05_Sol1_Cel
# --- Stimulus  : Sol_Cel3_P3_FL
# Average amount of motion (No. of pixels moving * strength of displacement): 1171.7568589
#
#
# ----------------------------------------------------------
# - Category    : 05_Sol1_Cel
# --- Stimulus  : Sol_Cel1_P3_MR
# Average amount of motion (No. of pixels moving * strength of displacement): 743.031740501
#
#
# ----------------------------------------------------------
# - Category    : 05_Sol1_Cel
# --- Stimulus  : Sol_Cel4_P2_FL
# Average amount of motion (No. of pixels moving * strength of displacement): 1387.78855148
#
#
# ----------------------------------------------------------
# - Category    : 05_Sol1_Cel
# --- Stimulus  : Sol_Cel7_P1_MR
# Average amount of motion (No. of pixels moving * strength of displacement): 1042.49575783
#
#
# ----------------------------------------------------------
# - Category    : 05_Sol1_Cel
# --- Stimulus  : Sol_Cel4_P2_MR
# Average amount of motion (No. of pixels moving * strength of displacement): 1313.75533431
#
#
# ----------------------------------------------------------
# - Category    : 05_Sol1_Cel
# --- Stimulus  : Sol_Cel1_P3_FL
# Average amount of motion (No. of pixels moving * strength of displacement): 826.050078235
#
#
# ----------------------------------------------------------
# - Category    : 05_Sol1_Cel
# --- Stimulus  : Sol_Cel3_P3_MR
# Average amount of motion (No. of pixels moving * strength of displacement): 626.626043077
#
#
# ----------------------------------------------------------
# - Category    : 09_Sol2_Lau
# --- Stimulus  : Sol_Lau2_P2_FR
# Average amount of motion (No. of pixels moving * strength of displacement): 866.888568476
#
#
# ----------------------------------------------------------
# - Category    : 09_Sol2_Lau
# --- Stimulus  : Sol_Lau4_P3_FR
# Average amount of motion (No. of pixels moving * strength of displacement): 680.189852541
#
#
# ----------------------------------------------------------
# - Category    : 09_Sol2_Lau
# --- Stimulus  : Sol_Lau5_P3_ML
# Average amount of motion (No. of pixels moving * strength of displacement): 629.109705307
#
#
# ----------------------------------------------------------
# - Category    : 09_Sol2_Lau
# --- Stimulus  : Sol_Lau2_P2_ML
# Average amount of motion (No. of pixels moving * strength of displacement): 655.043116553
#
#
# ----------------------------------------------------------
# - Category    : 09_Sol2_Lau
# --- Stimulus  : Sol_Lau5_P3_FR
# Average amount of motion (No. of pixels moving * strength of displacement): 637.65083815
#
#
# ----------------------------------------------------------
# - Category    : 09_Sol2_Lau
# --- Stimulus  : Sol_Lau1_P1_ML
# Average amount of motion (No. of pixels moving * strength of displacement): 684.160296113
#
#
# ----------------------------------------------------------
# - Category    : 09_Sol2_Lau
# --- Stimulus  : Sol_Lau1_P1_FR
# Average amount of motion (No. of pixels moving * strength of displacement): 517.675269135
#
#
# ----------------------------------------------------------
# - Category    : 09_Sol2_Lau
# --- Stimulus  : Sol_Lau4_P3_ML
# Average amount of motion (No. of pixels moving * strength of displacement): 584.176504571
#
#
# ----------------------------------------------------------
# - Category    : 08_Sol1_Lau
# --- Stimulus  : Sol_Lau1_P1_FL
# Average amount of motion (No. of pixels moving * strength of displacement): 524.87101199
#
#
# ----------------------------------------------------------
# - Category    : 08_Sol1_Lau
# --- Stimulus  : Sol_Lau5_P2_MR
# Average amount of motion (No. of pixels moving * strength of displacement): 795.451518908
#
#
# ----------------------------------------------------------
# - Category    : 08_Sol1_Lau
# --- Stimulus  : Sol_Lau4_P3_FL
# Average amount of motion (No. of pixels moving * strength of displacement): 681.929568416
#
#
# ----------------------------------------------------------
# - Category    : 08_Sol1_Lau
# --- Stimulus  : Sol_Lau4_P3_MR
# Average amount of motion (No. of pixels moving * strength of displacement): 578.988564714
#
#
# ----------------------------------------------------------
# - Category    : 08_Sol1_Lau
# --- Stimulus  : Sol_Lau2_P1_MR
# Average amount of motion (No. of pixels moving * strength of displacement): 714.308853345
#
#
# ----------------------------------------------------------
# - Category    : 08_Sol1_Lau
# --- Stimulus  : Sol_Lau1_P1_MR
# Average amount of motion (No. of pixels moving * strength of displacement): 688.077116863
#
#
# ----------------------------------------------------------
# - Category    : 08_Sol1_Lau
# --- Stimulus  : Sol_Lau2_P1_FL
# Average amount of motion (No. of pixels moving * strength of displacement): 543.592714493
#
#
# ----------------------------------------------------------
# - Category    : 08_Sol1_Lau
# --- Stimulus  : Sol_Lau5_P2_FL
# Average amount of motion (No. of pixels moving * strength of displacement): 403.458991937
#
#
# ----------------------------------------------------------
# - Category    : 02_Sol1_Arg
# --- Stimulus  : Sol_Arg2_P2_FL
# Average amount of motion (No. of pixels moving * strength of displacement): 740.967557322
#
#
# ----------------------------------------------------------
# - Category    : 02_Sol1_Arg
# --- Stimulus  : Sol_Arg3_P1_MR
# Average amount of motion (No. of pixels moving * strength of displacement): 784.167854724
#
#
# ----------------------------------------------------------
# - Category    : 02_Sol1_Arg
# --- Stimulus  : Sol_Arg2_P2_MR
# Average amount of motion (No. of pixels moving * strength of displacement): 1046.84718765
#
#
# ----------------------------------------------------------
# - Category    : 02_Sol1_Arg
# --- Stimulus  : Sol_Arg1_P2_MR
# Average amount of motion (No. of pixels moving * strength of displacement): 736.546245095
#
#
# ----------------------------------------------------------
# - Category    : 02_Sol1_Arg
# --- Stimulus  : Sol_Arg8_P3_MR
# Average amount of motion (No. of pixels moving * strength of displacement): 359.410059118
#
#
# ----------------------------------------------------------
# - Category    : 02_Sol1_Arg
# --- Stimulus  : Sol_Arg3_P1_FL
# Average amount of motion (No. of pixels moving * strength of displacement): 890.492262271
#
#
# ----------------------------------------------------------
# - Category    : 02_Sol1_Arg
# --- Stimulus  : Sol_Arg8_P3_FL
# Average amount of motion (No. of pixels moving * strength of displacement): 393.283157839
#
#
# ----------------------------------------------------------
# - Category    : 02_Sol1_Arg
# --- Stimulus  : Sol_Arg1_P2_FL
# Average amount of motion (No. of pixels moving * strength of displacement): 849.597328385
#
#
# ----------------------------------------------------------
# - Category    : 03_Sol2_Arg
# --- Stimulus  : Sol_Arg2_P3_FR
# Average amount of motion (No. of pixels moving * strength of displacement): 903.505753137
#
#
# ----------------------------------------------------------
# - Category    : 03_Sol2_Arg
# --- Stimulus  : Sol_Arg1_P2_FR
# Average amount of motion (No. of pixels moving * strength of displacement): 846.438612507
#
#
# ----------------------------------------------------------
# - Category    : 03_Sol2_Arg
# --- Stimulus  : Sol_Arg8_P1_ML
# Average amount of motion (No. of pixels moving * strength of displacement): 559.6267896
#
#
# ----------------------------------------------------------
# - Category    : 03_Sol2_Arg
# --- Stimulus  : Sol_Arg8_P1_FR
# Average amount of motion (No. of pixels moving * strength of displacement): 512.993176124
#
#
# ----------------------------------------------------------
# - Category    : 03_Sol2_Arg
# --- Stimulus  : Sol_Arg2_P3_ML
# Average amount of motion (No. of pixels moving * strength of displacement): 883.624805946
#
#
# ----------------------------------------------------------
# - Category    : 03_Sol2_Arg
# --- Stimulus  : Sol_Arg1_P2_ML
# Average amount of motion (No. of pixels moving * strength of displacement): 731.901297802
#
#
# ----------------------------------------------------------
# - Category    : 03_Sol2_Arg
# --- Stimulus  : Sol_Arg3_P1_FR
# Average amount of motion (No. of pixels moving * strength of displacement): 901.514875701
#
#
# ----------------------------------------------------------
# - Category    : 03_Sol2_Arg
# --- Stimulus  : Sol_Arg3_P1_ML
# Average amount of motion (No. of pixels moving * strength of displacement): 786.650188975
#
#
# ----------------------------------------------------------
# - Category    : 06_Sol2_Cel
# --- Stimulus  : Sol_Cel1_P3_FR
# Average amount of motion (No. of pixels moving * strength of displacement): 828.382998539
#
#
# ----------------------------------------------------------
# - Category    : 06_Sol2_Cel
# --- Stimulus  : Sol_Cel3_P1_ML
# Average amount of motion (No. of pixels moving * strength of displacement): 945.258061984
#
#
# ----------------------------------------------------------
# - Category    : 06_Sol2_Cel
# --- Stimulus  : Sol_Cel1_P3_ML
# Average amount of motion (No. of pixels moving * strength of displacement): 736.964580003
#
#
# ----------------------------------------------------------
# - Category    : 06_Sol2_Cel
# --- Stimulus  : Sol_Cel4_P2_FR
# Average amount of motion (No. of pixels moving * strength of displacement): 1399.67069233
#
#
# ----------------------------------------------------------
# - Category    : 06_Sol2_Cel
# --- Stimulus  : Sol_Cel7_P2_FR
# Average amount of motion (No. of pixels moving * strength of displacement): 805.554285905
#
#
# ----------------------------------------------------------
# - Category    : 06_Sol2_Cel
# --- Stimulus  : Sol_Cel7_P2_ML
# Average amount of motion (No. of pixels moving * strength of displacement): 1179.41215628
#
#
# ----------------------------------------------------------
# - Category    : 06_Sol2_Cel
# --- Stimulus  : Sol_Cel3_P1_FR
# Average amount of motion (No. of pixels moving * strength of displacement): 808.032536747
#
#
# ----------------------------------------------------------
# - Category    : 06_Sol2_Cel
# --- Stimulus  : Sol_Cel4_P2_ML
# Average amount of motion (No. of pixels moving * strength of displacement): 1309.27618816
#
#
# ----------------------------------------------------------

# %%
ma.averageAmountOfMotionToCSV(ma.loadMotionHistogramsToHeightMaps('C:\\Users\\Eler\\Documents\\Python Scripts\\Motion Analysis'))

# %% [markdown]
# Crosscorrelation manually

# %%
a = heightMaps['09_Sol2_Lau']['Sol_Lau4_P3_FR']
b = heightMaps['05_Sol1_Cel']['Sol_Cel3_P3_FL']

#a = np.asarray(a)[:,:80]
#b = np.asarray(b)[:,:80]
#ma.plotHeightMap(a)
#ma.plotHeightMap(b)

motionAcrossVideosForAllVideos = np.corrcoef(a,b)[35:,:35]
print(np.std(motionAcrossVideosForAllVideos))

# plotting the correlation matrix
from pylab import pcolor, show, yticks, xticks, colorbar
pcolor(motionAcrossVideosForAllVideos, cmap = 'plasma')
#yticks([0,8,17,26,35,44,53,62,70],[-180,-90,0,90,180,-90,0,90,180])

colorbar()
show()
# Out:
# 0.11198958002

# %% [markdown]
# Crosscorrelation for all pairs of clips

# %%
#Let's define an output list
standardDevCrossCorr = [[""]]

#Now lets run through our dictionary and save the Stimulus Names
#for category in list(heightMaps.keys()): #1. get the Category Name
#    for stimulus in list(heightMaps[category].keys()): # 2. get the stimulus Name
#        #print(stimulus)
#        standardDevCrossCorr.append([stimulus])
#        standardDevCrossCorr[0].append(stimulus)

for category in list(heightMaps.keys()):
    for stimulus, heightMap in heightMaps[category].items(): #    for heightMap in list(heightMaps[category].values()):
        #standardDevCrossCorr.append([stimulus])
        #standardDevCrossCorr[0].append(stimulus)
        standardDevCrossCorr.append([category])
        standardDevCrossCorr[0].append(category)
                

line = 1
for category in list(heightMaps.keys()):
    for stimulus, heightMap in heightMaps[category].items(): #    for heightMap in list(heightMaps[category].values()):
        for category1 in list(heightMaps.keys()):
            for stimulus1 ,heightMap1 in heightMaps[category1].items():
                
                #Make sure both heightMaps have the same shape. 
                #Discard if there are additional frmes in one video
                if(len(heightMap1[0])!=len(heightMap[0])):
                    frames = min(len(heightMap1[0]),len(heightMap[0]))
                    heightMap = np.asarray(heightMap)[:,:frames]
                    heightMap1 = np.asarray(heightMap1)[:,:frames]
                
                crossCor = np.corrcoef(heightMap,heightMap1)[35:,:35]
                standardDevCrossCorr[line].append(np.std(crossCor))
            
                #if(np.std(crossCor)>0.2  and (stimulus is not stimulus1)):
                #   print(stimulus + " vs. "+stimulus1)
                #   pcolor(crossCor, cmap = 'plasma')
                #    show()
                #    pcolor(heightMaps[category][stimulus], cmap = 'plasma')
                #    show()
                #    pcolor(heightMaps[category][stimulus1], cmap = 'plasma')
                #    show()
                #preceed with next row
        line += 1

# %%
standardDevCrossCorr=standardDevCrossCorr[1:]
standardDevCrossCorr=[standardDevCrossCorr[x][1:] for x in range(len(standardDevCrossCorr))]

standardDevCrossCorr = np.asarray(standardDevCrossCorr)
standardDevCrossCorr = standardDevCrossCorr.astype(np.float)
from pylab import pcolor, show, yticks, xticks, colorbar
pcolor(standardDevCrossCorr, cmap = 'plasma')
colorbar()
show()

# %%
from IPython.display import HTML, display
import tabulate
#table = [["a",1],["b",2]]
table = standardDevCrossCorr
display(HTML(tabulate.tabulate(table, tablefmt='html')))
# Out:
# <table>
# <tbody>
# <tr><td>           </td><td>05_Sol1_Cel        </td><td>05_Sol1_Cel        </td><td>05_Sol1_Cel        </td><td>05_Sol1_Cel        </td><td>05_Sol1_Cel        </td><td>05_Sol1_Cel        </td><td>05_Sol1_Cel        </td><td>05_Sol1_Cel        </td><td>09_Sol2_Lau        </td><td>09_Sol2_Lau        </td><td>09_Sol2_Lau        </td><td>09_Sol2_Lau        </td><td>09_Sol2_Lau        </td><td>09_Sol2_Lau        </td><td>09_Sol2_Lau        </td><td>09_Sol2_Lau        </td><td>08_Sol1_Lau        </td><td>08_Sol1_Lau        </td><td>08_Sol1_Lau        </td><td>08_Sol1_Lau        </td><td>08_Sol1_Lau        </td><td>08_Sol1_Lau        </td><td>08_Sol1_Lau        </td><td>08_Sol1_Lau        </td><td>02_Sol1_Arg        </td><td>02_Sol1_Arg        </td><td>02_Sol1_Arg        </td><td>02_Sol1_Arg        </td><td>02_Sol1_Arg        </td><td>02_Sol1_Arg        </td><td>02_Sol1_Arg        </td><td>02_Sol1_Arg        </td><td>03_Sol2_Arg        </td><td>03_Sol2_Arg        </td><td>03_Sol2_Arg        </td><td>03_Sol2_Arg        </td><td>03_Sol2_Arg        </td><td>03_Sol2_Arg        </td><td>03_Sol2_Arg        </td><td>03_Sol2_Arg        </td><td>06_Sol2_Cel        </td><td>06_Sol2_Cel        </td><td>06_Sol2_Cel        </td><td>06_Sol2_Cel        </td><td>06_Sol2_Cel        </td><td>06_Sol2_Cel        </td><td>06_Sol2_Cel        </td><td>06_Sol2_Cel        </td></tr>
# <tr><td>05_Sol1_Cel</td><td>0.2723871473849002 </td><td>0.12893530936218756</td><td>0.11541341802490812</td><td>0.1024118052135706 </td><td>0.15489752410522836</td><td>0.1441243864139593 </td><td>0.11864340011082844</td><td>0.1345062974627303 </td><td>0.07673473587715059</td><td>0.1135286228177063 </td><td>0.1267526609983288 </td><td>0.13166220421969085</td><td>0.13081538851664123</td><td>0.10999337165099596</td><td>0.13730631378031588</td><td>0.10723552939574016</td><td>0.13533146334039126</td><td>0.12587173856118739</td><td>0.11353618114796207</td><td>0.10833955022054709</td><td>0.10991451090008547</td><td>0.11223323465205258</td><td>0.12159834798053437</td><td>0.12350975332220474</td><td>0.11804421479681212</td><td>0.14043883883197944</td><td>0.1744367343826494 </td><td>0.11108234897548597</td><td>0.11126708634625548</td><td>0.1000201348971303 </td><td>0.13120739008000804</td><td>0.1207853203709655 </td><td>0.09924612977305663</td><td>0.12300136689463997</td><td>0.16680670268889797</td><td>0.16023350082850302</td><td>0.14486364997419562</td><td>0.11154718987593132</td><td>0.10048638170378175</td><td>0.13899084057298208</td><td>0.11744912751986177</td><td>0.15894629558520565</td><td>0.11565621564132943</td><td>0.1041413795332626 </td><td>0.17314764243117922</td><td>0.12262714990377135</td><td>0.15564318097152055</td><td>0.14445904643841723</td></tr>
# <tr><td>05_Sol1_Cel</td><td>0.12893530936218756</td><td>0.33499226048387515</td><td>0.1187860660105299 </td><td>0.13531288951067602</td><td>0.1441291117733578 </td><td>0.12898857752749995</td><td>0.14361102891981226</td><td>0.13935959793551336</td><td>0.11972681110287049</td><td>0.11198958002037417</td><td>0.14751110121114433</td><td>0.14180486462740924</td><td>0.1502223022405124 </td><td>0.14348095162300475</td><td>0.13037838156972237</td><td>0.11999449344997623</td><td>0.13086304414213618</td><td>0.13952943042024116</td><td>0.1120885875599786 </td><td>0.12162772987216484</td><td>0.1621125453381575 </td><td>0.14252293088332388</td><td>0.1456598242909116 </td><td>0.17689672500436154</td><td>0.1582613694821208 </td><td>0.1726004807539385 </td><td>0.14145975608642417</td><td>0.16395054478243426</td><td>0.10272279959099097</td><td>0.1249005075617737 </td><td>0.13538936933783144</td><td>0.1697225138070977 </td><td>0.16722525425468157</td><td>0.17216175955420981</td><td>0.11946469659280488</td><td>0.14187906057842298</td><td>0.11224557918684767</td><td>0.16204675156771473</td><td>0.1257893578917859 </td><td>0.17302658465014661</td><td>0.1423922977021439 </td><td>0.1642013166460833 </td><td>0.11799984770660939</td><td>0.1357448282677978 </td><td>0.14114659673429475</td><td>0.12290670204439769</td><td>0.11964551151647099</td><td>0.1282576563989943 </td></tr>
# <tr><td>05_Sol1_Cel</td><td>0.11541341802490812</td><td>0.1187860660105299 </td><td>0.3316495656281535 </td><td>0.15108644799636198</td><td>0.15894510889066318</td><td>0.14369598409125664</td><td>0.1341872030047122 </td><td>0.12496366533681595</td><td>0.14534207358008658</td><td>0.11818595315995582</td><td>0.11359812939715226</td><td>0.16108303218426534</td><td>0.17026640291859838</td><td>0.162561870618794  </td><td>0.1521194552449174 </td><td>0.11765710568066261</td><td>0.15064929310115155</td><td>0.13223344106265372</td><td>0.1183938314314327 </td><td>0.11702037743348173</td><td>0.12614760721604285</td><td>0.1671098790899233 </td><td>0.15711996882730384</td><td>0.17058215171765442</td><td>0.11359350621963642</td><td>0.12965850081534097</td><td>0.15177126079648162</td><td>0.13079218954564192</td><td>0.09985120672797579</td><td>0.13439119668173405</td><td>0.16196492010909166</td><td>0.12447659943648035</td><td>0.12586493709199487</td><td>0.12701320779587005</td><td>0.1465364094167275 </td><td>0.11605601612207712</td><td>0.14925878076416665</td><td>0.13307753811444406</td><td>0.1338723272389413 </td><td>0.12880360894332668</td><td>0.135693721590215  </td><td>0.1022783379187129 </td><td>0.3298797094354314 </td><td>0.15222718473688762</td><td>0.11319199479007526</td><td>0.13091265566576232</td><td>0.10997116825269612</td><td>0.14211115657011453</td></tr>
# <tr><td>05_Sol1_Cel</td><td>0.1024118052135706 </td><td>0.13531288951067602</td><td>0.15108644799636198</td><td>0.3134134779389662 </td><td>0.12374350579777359</td><td>0.12420833281077981</td><td>0.1278537168987461 </td><td>0.1279205890503911 </td><td>0.15086059663242854</td><td>0.12908314093065015</td><td>0.12048509197731427</td><td>0.1272375792214361 </td><td>0.15206970985581503</td><td>0.16913790083727204</td><td>0.14113770378341622</td><td>0.14508218195236858</td><td>0.13896172370215504</td><td>0.1570869566526198 </td><td>0.12869610634593495</td><td>0.14439191719641095</td><td>0.1251738373802622 </td><td>0.1711655879107057 </td><td>0.14090420046826993</td><td>0.16958935007254908</td><td>0.14371851398285224</td><td>0.14315259378266734</td><td>0.13895030362265076</td><td>0.1287913697285635 </td><td>0.12369551160358988</td><td>0.14369386017190985</td><td>0.14595619185705688</td><td>0.1272975809843719 </td><td>0.1315592867858637 </td><td>0.12659962935828095</td><td>0.1348133883794834 </td><td>0.12318658831567025</td><td>0.11889047551530615</td><td>0.12747300539665024</td><td>0.14251819983385378</td><td>0.1435289323453153 </td><td>0.12705888292410097</td><td>0.14259439700426602</td><td>0.15218686468309836</td><td>0.31197724722677667</td><td>0.14167090871490132</td><td>0.153962883592091  </td><td>0.11913372256992437</td><td>0.12434689685298611</td></tr>
# <tr><td>05_Sol1_Cel</td><td>0.15489752410522833</td><td>0.14412911177335777</td><td>0.15894510889066318</td><td>0.12374350579777359</td><td>0.2773578780581721 </td><td>0.12995924366095576</td><td>0.13595149684540098</td><td>0.12200241905119523</td><td>0.11526872232321907</td><td>0.13479249030601892</td><td>0.1299656322254691 </td><td>0.15133910548607982</td><td>0.14955940547588048</td><td>0.14852241259180746</td><td>0.1438574058739582 </td><td>0.12142092296820946</td><td>0.14191103110970926</td><td>0.13284719000796144</td><td>0.1352105231454354 </td><td>0.12188527511999632</td><td>0.1255572118223075 </td><td>0.1529115547749703 </td><td>0.1414005906535981 </td><td>0.16388816163869505</td><td>0.11786706142237668</td><td>0.1325053841406849 </td><td>0.13733590968727719</td><td>0.13325539432799197</td><td>0.13579651328358183</td><td>0.12517820297973545</td><td>0.15790401802165682</td><td>0.12404995562986085</td><td>0.11854075961433423</td><td>0.12611871273986144</td><td>0.14606190192582516</td><td>0.14316391933747716</td><td>0.1273105077637731 </td><td>0.13340807705540605</td><td>0.1256186392431803 </t

# %%
a = heightMaps['02_Sol1_Arg']['Sol_Arg1_P2_MR']
b = heightMaps['02_Sol1_Arg']['Sol_Arg1_P2_FL']
combine = a + b

motionAcrossVideosForAllVideos = np.corrcoef(a,b)

# plotting the correlation matrix
from pylab import pcolor, show, yticks, xticks, colorbar
pcolor(motionAcrossVideosForAllVideos, cmap = 'plasma')
yticks([0,8,17,26,35,44,53,62,70],[-180,-90,0,90,180,-90,0,90,180])

colorbar()
show()

# %%
num =0
for x in list(heightMaps.keys()): #How many videos are there in the folders?
    for y in list(heightMaps[x].keys()):
        num += 1
print(num)
# Out:
# 48

# %%
myList = [[0]*3 for x in range(3)]
myList[0][0]=1
myList
# Out:
# [[1, 0, 0], [0, 0, 0], [0, 0, 0]]

# %%
list(heightMaps[list(heightMaps.keys())[0]].keys())
# Out:
# ['Sol_Lau2_P2_FR',
#  'Sol_Lau4_P3_ML',
#  'Sol_Lau1_P1_FR',
#  'Sol_Lau5_P3_FR',
#  'Sol_Lau4_P3_FR',
#  'Sol_Lau2_P2_ML',
#  'Sol_Lau1_P1_ML',
#  'Sol_Lau5_P3_ML']

# %%
for category, v in heightMaps.items():
    if isinstance(v, dict):
        for stimulus, heightMap in v.items():
            #2. Again for each HeightMap - input2 to crosscorrelation
            for category1, v1 in heightMaps.items():
                if isinstance(v1, dict):
                    for stimulus1, heightMap1 in v.items():
                        crossCorrelation = np.corrcoef(heightMap,heightMap1)
                        #standardDevCrossCorr[1].append(np.std(crossCorrelation))
                        #std = np.std(crossCorrelation[35:,:35].flatten())
                else:
                    raise ValueError('Toplevel dictionary should only contain dictionaries')
    else:
        raise ValueError('Toplevel dictionary should only contain dictionaries')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-92f6b85f2253> in <module>()
#       6                 if isinstance(v1, dict):
#       7                     for stimulus1, heightMap1 in v.items():
# ----> 8                         crossCorrelation = np.corrcoef(heightMap,heightMap1)
#       9                         #standardDevCrossCorr[1].append(np.std(crossCorrelation))
#      10                         #std = np.std(crossCorrelation[35:,:35].flatten())
#
# C:\Users\Eler\Anaconda3\lib\site-packages\numpy\lib\function_base.py in corrcoef(x, y, rowvar, bias, ddof)
#    2559         warnings.warn('bias and ddof have no effect and are deprecated',
#    2560                       DeprecationWarning)
# -> 2561     c = cov(x, y, rowvar)
#    2562     try:
#    2563         d = diag(c)
#
# C:\Users\Eler\Anaconda3\lib\site-packages\numpy\lib\function_base.py in cov(m, y, rowvar, bias, ddof, fweights, aweights)
#    2430         if rowvar == 0 and y.shape[0] != 1:
#    2431             y = y.T
# -> 2432         X = np.vstack((X, y))
#    2433
#    2434     if ddof is None:
#
# C:\Users\Eler\Anaconda3\lib\site-packages\numpy\core\shape_base.py in vstack(tup)
#     228
#     229     """
# --> 230     return _nx.concatenate([atleast_2d(_m) for _m in tup], 0)
#     231
#     232 def hstack(tup):
#
# ValueError: all the input array dimensions except for the concatenation axis must match exactly
